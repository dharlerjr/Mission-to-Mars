# %% [markdown]
# ## Outdated Code

# %%
# Imports: Old
# from splinter import Browser
# from bs4 import BeautifulSoup as soup
# from webdriver_manager.chrome import ChromeDriverManager

# %%
# Set up Splinter: Old Method
# executable_path = {'executable_path': ChromeDriverManager().install()}
# browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## Practice with Splinter & BeautifulSoup

# %%
# Imports: Updated Feb 2024
from splinter import Browser
from bs4 import BeautifulSoup as soup
from selenium.webdriver.chrome.service import Service

# %%
# Set up Splinter: Updated 2024
my_service = Service(executable_path = 'C:\\Users\\David\\.wdm\\drivers\\chromedriver\\win64\\121.0.6167.184\\chromedriver-win32\\chromedriver.exe')
browser = Browser('chrome', service=my_service)

# %%
# Visit the Quotes to Scrape site
url = 'http://quotes.toscrape.com/'
browser.visit(url)

# %%
# Parse the HTML
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Scrape the Title
title = html_soup.find('h2').text
title
# Out:
# 'Top Ten tags'

# %%
# Scrape the top ten tags
tag_box = html_soup.find('div', class_='tags-box')

# tag_box
tags = tag_box.find_all('a', class_='tag')

for tag in tags:
    word = tag.text
    print(word)
# Out:
# love
# inspirational
# life
# humor
# books
# reading
# friendship
# friends
# truth
# simile

# %%
# Scrape First Five Pages for Quotes
for x in range(1, 6):
   html = browser.html
   quote_soup = soup(html, 'html.parser')
   quotes = quote_soup.find_all('span', class_='text')
   for quote in quotes:
      print('page:', x, '----------')
      print(quote.text)
   browser.links.find_by_partial_text('Next').click()
# Out:
# page: 1 ----------
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# page: 1 ----------
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# page: 1 ----------
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# page: 1 ----------
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# page: 1 ----------
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# page: 1 ----------
# “Try not to become a man of success. Rather become a man of value.”
# page: 1 ----------
# “It is better to be hated for what you are than to be loved for what you are not.”
# page: 1 ----------
# “I have not failed. I've just found 10,000 ways that won't work.”
# page: 1 ----------
# ...

# %% [markdown]
# ## More Practice

# %%
# Visit the BPL website
url = 'https://www.breakingpoint.gg/'
browser.visit(url)

# %%
# Parse the HTML
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Investigage the html_soup object created with BS4
html_soup
# Out:
# <html><head><script async="" src="https://static.criteo.net/js/ld/publishertag.prebid.134.js" type="text/javascript"></script><script async="" src="https://script.4dex.io/localstore.js" type="text/javascript"></script><style data-emotion="mantine ibbm6b 1acza3j osix87 1hdckxd 1c3kk2v 5f6x53 43n0fx 1672cyo xg7kom 1j8as5i 1g4q40w mbycnu 1buhfoz 37n0q3 2bz658 8zcx 17do188 1l9s2db 3ihc51 3xbgk5 qo1k2 26lut2 ndf8f2 isfpwv xlwgkm ylrjoj zrla8b 1r12ff0 dvrwgq 1a7c59l 1n76kkm 73o8aw 16qp3j5 1avyp1d h0ks6g 1se0g8v 1ljn1a7 o7byqr wrku18 khtkeg 1afll07 19titvp veertx x468zj 1a46vx3 hpmcve 1qlxz9s 43frxj fe043b 15pjuqq rc3ulo 1ifsn9r 1j4atyh 130ps8t 1ercgiq ypc0ee 1091sdc lj60le 1cp8ew k821wv 1csiak1 183vfyh jghxib smntue c5cyx3 1wuu4q3 1wg3rn8 17bd5gf bvyqyh xh7rb8 1tqbe04 7pdov2 fui8ih k4xypp vp2tbb 1p2dibx dd5k3n e1gfyf ccn972 ehts84 kvwtde wnos0g hhfxu9 4kybzh cnwdvq 1u8a6l z29d5u 7j9ynl 1k1q3d4 j98j9n ymxja8 qqmv3w 1yx5ug5 3y27yw q5fgt6 gk72te 97o3ov 879la3 tm2y6t jzhu2g 1gg3njf q34r9z 1ea2
# ...

# %%
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
# Navigate to the matches page on the BPL website
url = 'https://www.breakingpoint.gg/matches'
browser.visit(url)

# %%
# Parse the HTML
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Print the BeautifulSoup Object
html_soup
# Out:
# <html><head><script async="" src="https://static.criteo.net/js/ld/publishertag.prebid.134.js" type="text/javascript"></script><script async="" src="https://script.4dex.io/localstore.js" type="text/javascript"></script><style data-emotion="mantine ibbm6b 1acza3j osix87 1hdckxd 1c3kk2v 5f6x53 43n0fx 1672cyo xg7kom 1j8as5i 1g4q40w mbycnu 1buhfoz 37n0q3 2bz658 8zcx 17do188 1l9s2db 3ihc51 3xbgk5 qo1k2 26lut2 ndf8f2 isfpwv xlwgkm ylrjoj zrla8b 1r12ff0 dvrwgq 1a7c59l 1n76kkm 73o8aw 16qp3j5 1avyp1d h0ks6g 1se0g8v 1ljn1a7 o7byqr wrku18 khtkeg fe043b 15pjuqq rc3ulo 1ifsn9r x468zj 1j4atyh 130ps8t 45aznk o7t6d4 12cn9q qpfyir fui8ih 7j9ynl 1123ma0 19ww551 jb2kzm 1vexleb 15he3b8 1qpq0p5 1vcz0p4 1vc2gpw 7aycx2 12sbrde 5dili5 29b1mk 1evf4wh 1bvkcnr 8s4k3m 70pi5x 1e049xz cd9uk2 1hiehc6 11q5icf" data-s="">.mantine-ibbm6b{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;}.mantine-1acza3j{-webkit-flex:1;-ms-flex:1;flex:1;width:100vw;box-sizing:border-box;mi
# ...
